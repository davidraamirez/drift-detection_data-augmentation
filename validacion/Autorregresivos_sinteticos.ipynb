# %%
# %run FUNCIONES_GENERALES.ipynb
# Out:
# /home/khaosdev/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/khaosdev/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (

# %% [markdown]
# MODELOS SARIMAX STATMODELS:

# %%
import numpy as np
import pandas as pd
  
from sklearn import metrics
from math import sqrt

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

import time
import itertools
import warnings
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA

warnings.filterwarnings("ignore")

# %% [markdown]
# Ejemplo general:

# %%
fecha1='1/1/2012'

# %%
fecha2='1/1/2024'

# %%
fecha3='1/1/2026'

# %%
df1 = crear_df_fin_tend_det(fecha1,fecha3,'M',['Precio'],[400,0.6],1,0.2)

# %%
df1_train = df1[:144]

# %%
df1_test = df1[144:]

# %%
p = d = q = range(0, 3)
pdq = list(itertools.product(p, d, q))

# %%
seasonal_pdq = [(0, 0, 0, 0)]

# %%
st = time.time()

best_score = 0
best_params = None
best_seasonal_params = None

for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            
            mod = sm.tsa.statespace.SARIMAX(df1_train,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity = False,
                                            enforce_invertibility = False)

            results = mod.fit()

            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
            
            # guardamos el mejor resultado
            if best_score == 0:
                best_score = results.aic
                best_params = param
                best_seasonal_params = param_seasonal
                
            elif abs(results.aic) < abs(best_score):
                best_score = results.aic
                best_params = param
                best_seasonal_params = param_seasonal
            
        # alguna combinación de parámetros en SARIMAX, no son válidos
        # y los vamos a cazar con un except
        except:
            continue

et = time.time()

print("La búsqueda de parámetros nos ha llevado {} minutos!".format((et - st)/60))
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.46389D+00    |proj g|=  2.91269D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      0      1      0     0     0   2.913D-06   7.464D+00
#   F =   7.4638915922944289
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 0)x(0, 0, 0, 0)12 - AIC:2151.6007785807956
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.12033D+01    |proj g|=  1.28076D-02
#   ys=-9.879E+00  -gs= 9.316E-01 BFGS update SKIPPED
#
# At iterate    5    f=  7.03679D+00    |proj g|=  1.65447D-03
#
# At iterate   10    f=  7.03674D+00    |proj g|=  2.27698D-02
#
# At iterate   15    f=  7.02304D+00    |proj g|=  5.63047D-01
#
# At iterate   20    f=  6.75966D+00    |proj g|=  4.88602D-02
#
# At iterate   25    f=  6.74895D+00    |proj g|=  3.75170D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     26     53      2     1     0   4.498D-07   6.749D+00
#   F =   6.7489522041126158
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 1)x(0, 0, 0, 0)12 - AIC:1947.6982347844335
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.07950D+01    |proj g|=  1.77984D-02
#
# At iterate    5    f=  8.01017D+00    |proj g|=  2.59603D-01
#
# At iterate   10    f=  7.40818D+00    |proj g|=  1.16159D+00
#
# At iterate   15    f=  6.94474D+00    |proj g|=  8.04951D-02
#
# At iterate   20    f=  6.91263D+00    |proj g|=  9.50325D-03
#
# At iterate   25    f=  6.90913D+00    |proj g|=  4.77762D-02
#
# At iterate   30    f=  6.83255D+00    |proj g|=  2.61939D-01
#
# At iterate   35    f=  6.06606D+00    |proj g|=  1.97189D-01
#
# At iterate   40    f=  6.05737D+00    |proj g|=  1.43327D-02
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     43     96      1     0     0   4.959D-05   6.057D+00
#   F =   6.0573660173873147
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(0, 0, 2)x(0, 0, 0, 0)12 - AIC:1750.5214130075467
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.04570D-01    |proj g|=  1.31321D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      2      6      1     0     0   2.970D-05   9.046D-01
#   F =  0.90455402869394419
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(0, 1, 0)x(0, 0, 0, 0)12 - AIC:262.5115602638559
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.88995D-01    |proj g|=  6.41636D-01
#
# At iterate    5    f=  4.17309D-01    |proj g|=  2.92627D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      8
+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     42     82      1     0     0   2.128D+00  -1.186D+00
#   F =  -1.1856253068121800
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(2, 1, 2)x(0, 0, 0, 0)12 - AIC:-331.4600883619079
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -8.88729D-01    |proj g|=  1.06905D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      1     12      1     0     0   1.086D-03  -8.887D-01
#   F = -0.88872882431485101
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(2, 2, 0)x(0, 0, 0, 0)12 - AIC:-249.95390140267708
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.03661D+00    |proj g|=  1.46135D+00
#
# At iterate    5    f= -1.07926D+00    |proj g|=  2.75119D+00
#
# At iterate   10    f= -1.18168D+00    |proj g|=  8.61828D-02
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate   15    f= -1.18498D+00    |proj g|=  4.98088D-03
#
# At iterate   20    f= -1.18499D+00    |proj g|=  7.86942D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     20     34      1     0     0   7.869D-04  -1.185D+00
#   F =  -1.1849892293762603
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(2, 2, 1)x(0, 0, 0, 0)12 - AIC:-333.27689806036295
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.04431D+00    |proj g|=  1.79211D+00
#
# At iterate    5    f= -1.08904D+00    |proj g|=  2.54653D+00
#
# At iterate   10    f= -1.13114D+00    |proj g|=  1.81703D-01
#
# At iterate   15    f= -1.13520D+00    |proj g|=  6.78364D-02
#
# At iterate   20    f= -1.13790D+00    |proj g|=  5.51430D-01
#
# At iterate   25    f= -1.15060D+00    |proj g|=  1.10799D+00
#
# At iterate   30    f= -1.29909D+00    |proj g|=  6.97593D-02
#
# At iterate   35    f= -1.30332D+00    |proj g|=  4.62516D-01
#
# At iterate   40    f= -1.30445D+00    |proj g|=  5.21104D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     43     75      1     0     0   1.599D-02  -1.304D+00
#   F =  -1.3044644571025019
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(2, 2, 2)x(0, 0, 0, 0)12 - AIC:-365.6857636455205
# La búsqueda de parámetros nos ha llevado 0.0292553981145223 minutos!
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.

# %%
print("El mejor modelo es {}, \nCon un AIC de {}".format(best_params, best_score))
# Out:
# El mejor modelo es (0, 1, 2),
# Con un AIC de 48.092828992578006

# %%
mod = sm.tsa.statespace.SARIMAX(df1_train,
                                order = best_params,
                                seasonal_order = param_seasonal,
                                enforce_stationarity = False,
                                enforce_invertibility = False)

results = mod.fit()
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.22793D+00    |proj g|=  2.10890D+00
#
# At iterate    5    f=  1.98495D-01    |proj g|=  4.67901D-01
#
# At iterate   10    f=  1.46156D-01    |proj g|=  1.18428D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     11     19      1     0     0   5.125D-06   1.462D-01
#   F =  0.14615565622422919
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.

# %%
# Para hacer una predicción es suficiente con especificar el número de steps/pasos futuros a estimar.
pred_uc = results.get_forecast(steps = len(df1_test))

# Calcula el intervalo de confianza de la predicción.
pred_ci = pred_uc.conf_int()

# %%
pred_uc.predicted_mean
# Out:
# 2024-01-31    486.448422
# 2024-02-29    486.356507
# 2024-03-31    486.356507
# 2024-04-30    486.356507
# 2024-05-31    486.356507
# 2024-06-30    486.356507
# 2024-07-31    486.356507
# 2024-08-31    486.356507
# 2024-09-30    486.356507
# 2024-10-31    486.356507
# 2024-11-30    486.356507
# 2024-12-31    486.356507
# 2025-01-31    486.356507
# 2025-02-28    486.356507
# 2025-03-31    486.356507
# 2025-04-30    486.356507
# 2025-05-31    486.356507
# 2025-06-30    486.356507
# 2025-07-31    486.356507
# 2025-08-31    486.356507
# 2025-09-30    486.356507
# 2025-10-31    486.356507
# 2025-11-30    486.356507
# 2025-12-31    486.356507
# Freq: ME, Name: predicted_mean, dtype: float64

# %%
ax = df1_test.plot(label = 'Valores reales', figsize = (20, 15))

pred_uc.predicted_mean.plot(ax = ax, label = 'Predicción')

ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color = 'k', alpha = .25)

ax.set_xlabel('Tiempo')
ax.set_ylabel('Precio')

plt.legend()
plt.show()

# %%
df2 = crear_df_fin_tend_det(fecha1,fecha3,'M',['Precio'],[3,0.2],3,0.2)

# %%
df2_train = df2[:144]
df2_test = df2[144:]

# %%
p = d = q = range(0, 3)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(0, 0, 0, 0)]

# %%
st = time.time()

best_score = 0
best_params = None
best_seasonal_params = None

for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            
            mod = sm.tsa.statespace.SARIMAX(df2_train,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity = False,
                                            enforce_invertibility = False)

            results = mod.fit()

            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
            
            # guardamos el mejor resultado
            if best_score == 0:
                best_score = results.aic
                best_params = param
                best_seasonal_params = param_seasonal
                
            elif abs(results.aic) < abs(best_score):
                best_score = results.aic
                best_params = param
                best_seasonal_params = param_seasonal
            
        # alguna combinación de parámetros en SARIMAX, no son válidos
        # y los vamos a cazar con un except
        except:
            continue

et = time.time()

print("La búsqueda de parámetros nos ha llevado {} minutos!".format((et - st)/60))
# Out:
#  This problem is unconstrained.
#  This problem is unconstrained.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.12007D+01    |proj g|=  6.52115D-16
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      0      1      0     0     0   6.521D-16   3.120D+01
#   F =   31.200741876014590
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 0)x(0, 0, 0, 0)12 - AIC:8987.813660292202
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.60793+192    |proj g|=  3.67641+194
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      1     21      1     0     0   3.676+194   7.608+192
#   F =   7.6079264205133523E+192
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(0, 0, 1)x(0, 0, 0, 0)12 - AIC:2.1910828091078455e+195
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.17587D+01    |proj g|=  3.47595+249
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      1     21      1     0     0   3.476+249   3.176D+01
#   F =   31.758715281044438
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(0, 0, 2)x(0, 0, 0, 0)12 - AIC:9152.510000940798
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.95098D+01    |proj g|=  5.82834D-15
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      0      1      0     0     0   5.828D-15   2.951D+01
#   F =   29.509758110891326
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 0)x(0, 0, 0, 0)12 - AIC:8500.810335936701
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.30306D+01    |proj g|=  2.21207D+01
#
# At iterate    5    f=  2.91040D+01    |proj g|=  3.37303D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      6      8      1     0     0   4.492D-06   2.910D+01
#   F =   29.103974591532946
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 1)x(0, 0, 0, 0)12 - AIC:8385.944682361489
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.75975+124    |proj g|=  3.75975+129
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      2     44      2     0     0         NaN   3.208D+02
#   F =   320.81591436823408
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(0, 1, 2)x(0, 0, 0, 0)12 - AIC:92400.98333805142
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.87424D+01    |proj g|=  1.55374D-14
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      0      1      0     0     0   1.554D-14   2.874D+01
#   F =   28.742356281865113
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 2, 0)x(0, 0, 0, 0)12 - AIC:8279.798609177153
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.85798D+01    |proj g|=  5.31030D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4      6      1     0     0   2.913D-08   2.850D+01
#   F =   28.504592883445159
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 2, 1)x(0, 0, 0, 0)12 - AIC:8213.322750432206
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.82585D+01    |proj g|=  8.90816D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      4     29      1     0     0   2.209D+06   6.430D+00
#   F =   6.4299224592062165
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(0, 2, 2)x(0, 0, 0, 0)12 - AIC:1857.8176682513904
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.87147D+01    |proj g|=  4.61110D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      1     14      1     0     0   4.609D-04   2.871D+01
#   F =   28.714726413295594
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(1, 0, 0)x(0, 0, 0, 0)12 - AIC:8273.84120702913
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2

#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      1      3      1     0     0   2.112D+04   2.042D+01
#   F =   20.420832321988208
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(2, 1, 1)x(0, 0, 0, 0)12 - AIC:5889.1997087326035
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.81882D+01    |proj g|=  5.32677D-01
#
# At iterate    5    f=  9.88931D+00    |proj g|=  3.25995D+13
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5      6     19      1     0     0   3.260D+13   9.889D+00
#   F =   9.8893083123816652
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(2, 1, 2)x(0, 0, 0, 0)12 - AIC:2858.12079396592
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.82200D+01    |proj g|=  8.92086D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      0      1      0     0     0   8.921D-06   2.822D+01
#   F =   28.219995158180435
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(2, 2, 0)x(0, 0, 0, 0)12 - AIC:8133.358605555965
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.83020D+01    |proj g|=  6.35074D-01
#
# At iterate    5    f=  2.81976D+01    |proj g|=  1.71775D-02
#
# At iterate   10    f=  2.81951D+01    |proj g|=  1.03867D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     11     13      1     0     0   1.376D-06   2.820D+01
#   F =   28.195115549447102
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(2, 2, 1)x(0, 0, 0, 0)12 - AIC:8128.193278240766
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.79474D+01    |proj g|=  5.65376D-01
#
# At iterate    5    f=  1.59815D+01    |proj g|=  9.71074D+04
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5      6     65      2     0     0   9.711D+04   1.598D+01
#   F =   15.981492395731230
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(2, 2, 2)x(0, 0, 0, 0)12 - AIC:4612.6698099705945
# La búsqueda de parámetros nos ha llevado 0.022922082742055257 minutos!
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.

# %%
print("El mejor modelo es {}, \nCon un AIC de {}".format(best_params, best_score))
# Out:
# El mejor modelo es (0, 2, 2),
# Con un AIC de 1857.8176682513904

# %%
mod = sm.tsa.statespace.SARIMAX(df2_train,
                                order = best_params,
                                seasonal_order = param_seasonal,
                                enforce_stationarity = False,
                                enforce_invertibility = False)

results = mod.fit()
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.82585D+01    |proj g|=  8.90816D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      4     29      1     0     0   2.209D+06   6.430D+00
#   F =   6.4299224592062165
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.

# %%
# Para hacer una predicción es suficiente con especificar el número de steps/pasos futuros a estimar.
pred_uc = results.get_forecast(steps = len(df2_test))

# Calcula el intervalo de confianza de la predicción.
pred_ci = pred_uc.conf_int()

# %%
pred_uc.predicted_mean
# Out:
# 2024-01-31    2.663768e+14
# 2024-02-29    2.693698e+14
# 2024-03-31    2.723629e+14
# 2024-04-30    2.753560e+14
# 2024-05-31    2.783491e+14
# 2024-06-30    2.813422e+14
# 2024-07-31    2.843352e+14
# 2024-08-31    2.873283e+14
# 2024-09-30    2.903214e+14
# 2024-10-31    2.933145e+14
# 2024-11-30    2.963075e+14
# 2024-12-31    2.993006e+14
# 2025-01-31    3.022937e+14
# 2025-02-28    3.052868e+14
# 2025-03-31    3.082798e+14
# 2025-04-30    3.112729e+14
# 2025-05-31    3.142660e+14
# 2025-06-30    3.172591e+14
# 2025-07-31    3.202521e+14
# 2025-08-31    3.232452e+14
# 2025-09-30    3.262383e+14
# 2025-10-31    3.292314e+14
# 2025-11-30    3.322245e+14
# 2025-12-31    3.352175e+14
# Freq: ME, Name: predicted_mean, dtype: float64

# %%
ax = df2_test.plot(label = 'Valores reales', figsize = (20, 15))

pred_uc.predicted_mean.plot(ax = ax, label = 'Predicción')

ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color = 'k', alpha = .25)

ax.set_xlabel('Tiempo')
ax.set_ylabel('Precio')

plt.legend()
plt.show()
