# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("updated_pollution_dataset_numeric.csv")

# %%
df1=df.drop('Air Quality', axis=1)

# %%
df1['Air Quality Numeric'] = df1['Air Quality Numeric'] + np.random.random(size=df1.shape[0])*10

# %%
df1
# Out:
#             Temperature  Humidity  PM2.5  PM10   NO2   SO2    CO  \
# 2010-01-31         29.8      59.1    5.2  17.9  18.9   9.2  1.72
# 2010-02-28         28.3      75.6    2.3  12.2  30.8   9.7  1.64
# 2010-03-31         23.1      74.7   26.7  33.8  24.4  12.6  1.63
# 2010-04-30         27.1      39.1    6.1   6.3  13.5   5.3  1.15
# 2010-05-31         26.5      70.7    6.9  16.0  21.9   5.6  1.01
# ...                 ...       ...    ...   ...   ...   ...   ...
# 2051-04-30         21.5      54.4   24.5  28.6  17.8   5.5  0.91
# 2051-05-31         24.4      48.1   21.9  29.7  11.1  12.7  0.97
# 2051-06-30         32.6      58.9   30.8  38.8  30.9  17.5  1.85
# 2051-07-31         34.3      81.2   32.2  47.1  31.7  16.5  1.71
# 2051-08-31         35.2      82.6   24.9  43.4  36.3   8.1  1.99
#
#             Proximity_to_Industrial_Areas  Population_Density  \
# 2010-01-31                            6.3                 319
# 2010-02-28                            6.0                 611
# 2010-03-31                            5.2                 619
# 2010-04-30                           11.1                 551
# 2010-05-31                           12.7                 303
# ...                                   ...                 ...
# 2051-04-30                           10.9                 289
# 2051-05-31                           10.6                 572
# 2051-06-30                            4.9                 448
# 2051-07-31                            3.9                 507
# 2051-08-31                            5.7                 419
#
#             Air Quality Numeric
# 2010-01-31            56.905278
# 2010-02-28            61.169415
# 2010-03-31            57.915066
# 2010-04-30            91.995568
# 2010-05-31            86.128637
# ...                         ...
# 2051-04-30            91.947946
# 2051-05-31            85.022992
# 2051-06-30            31.610634
# 2051-07-31            38.009700
# 2051-08-31            35.886198
#
# [500 rows x 10 columns]

# %%
def series_periodos(inicio, periodos, freq): 
    serie = pd.date_range(start=inicio, periods=periodos, freq=freq)
    return serie

# %%
indice=series_periodos('1/1/2010',df1.shape[0],'M')

# %%
df1.index=indice

# %%
df1.to_csv("Preprocesado.csv",index_label="indice")

# %%
df1 = df1[:500]
